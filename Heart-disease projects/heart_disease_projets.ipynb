# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('heart_disease.csv')
data['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
data.drop(columns=['education'])
# data['Gender'].unique()
# Out:
#       Gender  age  currentSmoker  cigsPerDay  BPMeds prevalentStroke  \
# 0          1   39              0         0.0     0.0              no
# 1          0   46              0         0.0     0.0              no
# 2          1   48              1        20.0     0.0              no
# 3          0   61              1        30.0     0.0              no
# 4          0   46              1        23.0     0.0              no
# ...      ...  ...            ...         ...     ...             ...
# 4233       1   50              1         1.0     0.0              no
# 4234       1   51              1        43.0     0.0              no
# 4235       0   48              1        20.0     NaN              no
# 4236       0   44              1        15.0     0.0              no
# 4237       0   52              0         0.0     0.0              no
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# ...

# %%
data['Gender'] = data['Gender'].replace(['Male','Female'],[1,0])
# data.drop(columns=['education'],inplace=True)
data['prevalentStroke'] = data['prevalentStroke'].replace(['no','yes'],[1,0])

# %%
data['prevalentStroke'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
data
# Out:
#       Gender  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0          1   39              0         0.0     0.0                1
# 1          0   46              0         0.0     0.0                1
# 2          1   48              1        20.0     0.0                1
# 3          0   61              1        30.0     0.0                1
# 4          0   46              1        23.0     0.0                1
# ...      ...  ...            ...         ...     ...              ...
# 4233       1   50              1         1.0     0.0                1
# 4234       1   51              1        43.0     0.0                1
# 4235       0   48              1        20.0     NaN                1
# 4236       0   44              1        15.0     0.0                1
# 4237       0   52              0         0.0     0.0                1
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# ...

# %%
data.dropna(inplace=True)
data['Heart_ stroke'].unique()
# Out:
# array(['No', 'yes'], dtype=object)

# %%
data['Heart_ stroke'] = data['Heart_ stroke'].replace(['No' ,'yes'],[0,1])

# %%
data
# Out:
#       Gender  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0          1   39              0         0.0     0.0                1
# 1          0   46              0         0.0     0.0                1
# 2          1   48              1        20.0     0.0                1
# 3          0   61              1        30.0     0.0                1
# 4          0   46              1        23.0     0.0                1
# ...      ...  ...            ...         ...     ...              ...
# 4231       1   58              0         0.0     0.0                1
# 4232       1   68              0         0.0     0.0                1
# 4233       1   50              1         1.0     0.0                1
# 4234       1   51              1        43.0     0.0                1
# 4237       0   52              0         0.0     0.0                1
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# ...

# %%
#input , output create

# %%
input_dataset = data.drop(columns=['Heart_ stroke'])
output_dataset = data['Heart_ stroke']
input_dataset
# Out:
#       Gender  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0          1   39              0         0.0     0.0                1
# 1          0   46              0         0.0     0.0                1
# 2          1   48              1        20.0     0.0                1
# 3          0   61              1        30.0     0.0                1
# 4          0   46              1        23.0     0.0                1
# ...      ...  ...            ...         ...     ...              ...
# 4231       1   58              0         0.0     0.0                1
# 4232       1   68              0         0.0     0.0                1
# 4233       1   50              1         1.0     0.0                1
# 4234       1   51              1        43.0     0.0                1
# 4237       0   52              0         0.0     0.0                1
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose
# ...

# %%
# print(len(input_dataset))
# print(len(output_dataset))

# %%
output_dataset.value_counts()
#impalanced data not equal
# Out:
# Heart_ stroke
# 0    3177
# 1     572
# Name: count, dtype: int64

# %%
pip install imblearn
# Out:
# ...
#
# ...

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=2)
input_dataset,output_dataset=sm.fit_resample(input_dataset,output_dataset.ravel())
np.unique(data_output , return_counts=True)
# data is equal
# Out:
# (array([0, 1], dtype=int64), array([3177, 3177], dtype=int64))

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
x_train,x_test,y_train,y_test = train_test_split(input_dataset,output_dataset, test_size=0.2)
model = LogisticRegression()
model.fit(x_train,y_train)
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.6514555468135327

# %%
model.score(x_test,y_test)
# Out:
# 0.6514555468135327

# %%
input = np.array([[0,61,1,30,0,0,1,0,225,150,95,28.58,65,103]])
model.predict(input)
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
# pip install pickle5
# visual start

# %%
import pickle as pk
pk.dump(model,open('Heart_disease_model.pk1','wb'))

# %%
pip install streamlit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
